# %% [markdown]
# # Example 1.1

# %% [markdown]
# barcycle(data)                              % Plots the load cycle
# xlabel('Time, hr'), ylabel('P, MW'), grid

# %%
#using Pkg;
#Pkg.add("Revise")
using Revise

# %%
data = [ 0   2    6
         2   6    5
         6   9   10
         9  12   15
        12  14   12
        14  16   14
        16  18   16
        18  20   18
        20  22   16
        22  23   12
        23  24    6]
# Out:
# 11×3 Matrix{Int64}:
#   0   2   6
#   2   6   5
#   6   9  10
#   9  12  15
#  12  14  12
#  14  16  14
#  16  18  16
#  18  20  18
#  20  22  16
#  22  23  12
#  23  24   6

# %%
P =data[:,3]                           #Column array of load
# Out:
# 11-element Vector{Int64}:
#   6
#   5
#  10
#  15
#  12
#  14
#  16
#  18
#  16
#  12
#   6

# %%
Dt = data[:, 2] - data[:,1]    #Column array of demand interval
# Out:
# 11-element Vector{Int64}:
#  2
#  4
#  3
#  3
#  2
#  2
#  2
#  2
#  2
#  1
#  1

# %%
W = P'*Dt                # Total energy, area under the curve
# Out:
# 277

# %%
Pavg = W/sum(Dt)                                    # Average load
# Out:
# 11.541666666666666

# %%
P'
# Out:
# 1×11 adjoint(::Vector{Int64}) with eltype Int64:
#  6  5  10  15  12  14  16  18  16  12  6

# %%
Peak = maximum(P)                                          # Peak load
# Out:
# 18

# %%
LF = Pavg/Peak*100                           # Percent load factor
# Out:
# 64.12037037037037

# %%
# uncomment following lines if NBInclude is not installed
#using Pkg
#Pkg.add("NBInclude")

# %%
using NBInclude
@nbinclude("barcycle.ipynb")
# Out:
# barcycle (generic function with 1 method)

# %%
barcycle(data)
# Out:
# try30
